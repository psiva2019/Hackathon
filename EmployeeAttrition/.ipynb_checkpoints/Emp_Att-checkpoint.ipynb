# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#df_train=pd.read_csv('/kaggle/input/employeeattrition/Train_Dataset.csv')
#df_test=pd.read_csv('/kaggle/input/employeeattrition/Test_Dataset.csv')

df_train=pd.read_csv('Train_Dataset.csv')
df_test=pd.read_csv('Test_Dataset.csv')

# %%
#Shape of the Data
print('****Shape of the train data****')
print('*************************')
print('No of rows\t:\t{}\nNo of columns\t:\t{}'.format(df_train.shape[0],df_train.shape[1]))

#Shape of the Data
print('\n****Shape of the test data****')
print('*************************')
print('No of rows\t:\t{}\nNo of columns\t:\t{}'.format(df_test.shape[0],df_test.shape[1]))
# Out:
# ****Shape of the train data****
# *************************
# No of rows	:	5180
# No of columns	:	22
#
# ****Shape of the test data****
# *************************
# No of rows	:	2630
# No of columns	:	21

# %%
print('****Show infomation of the train data****')
print('***********************************')
df_train.info()
# Out:
# ****Show infomation of the train data****
# ***********************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          5180 non-null   int64
#  1   Attrition           5180 non-null   int64
#  2   Age                 4864 non-null   float64
#  3   TravelProfile       5180 non-null   object
#  4   Department          5056 non-null   object
#  5   HomeToWork          4925 non-null   float64
#  6   EducationField      5180 non-null   object
#  7   Gender              5134 non-null   object
#  8   HourlnWeek          4893 non-null   float64
#  9   Involvement         5180 non-null   int64
#  10  WorkLifeBalance     5180 non-null   int64
#  11  Designation         5142 non-null   object
#  12  JobSatisfaction     5180 non-null   int64
#  13  ESOPs               5180 non-null   int64
# ...

# %%
print('****Show infomation of the test data****')
print('***********************************')
df_test.info()
# Out:
# ****Show infomation of the test data****
# ***********************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          2630 non-null   int64
#  1   Age                 2488 non-null   float64
#  2   TravelProfile       2630 non-null   object
#  3   Department          2572 non-null   object
#  4   HomeToWork          2504 non-null   float64
#  5   EducationField      2630 non-null   object
#  6   Gender              2600 non-null   object
#  7   HourlnWeek          2494 non-null   float64
#  8   Involvement         2630 non-null   int64
#  9   WorkLifeBalance     2630 non-null   int64
#  10  Designation         2600 non-null   object
#  11  JobSatisfaction     2630 non-null   int64
#  12  ESOPs               2630 non-null   int64
#  13  NumCompaniesWorked  2630 non-null   int64
# ...

# %% [markdown]
# * There are number of null values in the data set
# * There are 6 catagorical variable in the data set

# %%
tvar='Attrition'
perclass = df_train[tvar].value_counts(normalize=True)
tardisval = df_train[tvar].value_counts()
print('****Target Varible Distribution****')
print('************************************')
print('{} - Yes \t:\t {} which is {}% \n{} - No\t\t:\t {} which is {}%'.format(tvar,tardisval[1],round(perclass[1]*100,2),tvar,tardisval[0],round(perclass[0]*100,2)))
# Out:
# ****Target Varible Distribution****
# ************************************
# Attrition - Yes 	:	 1445 which is 27.9%
# Attrition - No		:	 3735 which is 72.1%

# %% [markdown]
# * Target variable is imbalanced

# %%
#Check for missing value
print('****Missing Values in the Dataset****')
print('*************************************')
msv = df_train.isnull().sum()[df_train.isnull().sum()>0]
if msv.empty:
    print('There is no missing values in the data.') 
else:
    for i in range(msv.count()):
        print('{} Missing values in {} which is {}% of total data'.format(msv[i],msv.index[i],round(((msv[i]/df_train.shape[0])*100),2)))
# Out:
# ****Missing Values in the Dataset****
# *************************************
# 316 Missing values in Age which is 6.1% of total data
# 124 Missing values in Department which is 2.39% of total data
# 255 Missing values in HomeToWork which is 4.92% of total data
# 46 Missing values in Gender which is 0.89% of total data
# 287 Missing values in HourlnWeek which is 5.54% of total data
# 38 Missing values in Designation which is 0.73% of total data
# 169 Missing values in SalaryHikelastYear which is 3.26% of total data
# 187 Missing values in WorkExperience which is 3.61% of total data
# 70 Missing values in LastPromotion which is 1.35% of total data
# 311 Missing values in CurrentProfile which is 6.0% of total data
# 93 Missing values in MonthlyIncome which is 1.8% of total data

# %%
#Check for missing value
print('****Missing Values in the Dataset****')
print('*************************************')
msv = df_test.isnull().sum()[df_test.isnull().sum()>0]
if msv.empty:
    print('There is no missing values in the data.') 
else:
    for i in range(msv.count()):
        print('{} Missing values in {} which is {}% of total data'.format(msv[i],msv.index[i],round(((msv[i]/df_test.shape[0])*100),2)))
# Out:
# ****Missing Values in the Dataset****
# *************************************
# 142 Missing values in Age which is 5.4% of total data
# 58 Missing values in Department which is 2.21% of total data
# 126 Missing values in HomeToWork which is 4.79% of total data
# 30 Missing values in Gender which is 1.14% of total data
# 136 Missing values in HourlnWeek which is 5.17% of total data
# 30 Missing values in Designation which is 1.14% of total data
# 94 Missing values in SalaryHikelastYear which is 3.57% of total data
# 122 Missing values in WorkExperience which is 4.64% of total data
# 57 Missing values in LastPromotion which is 2.17% of total data
# 134 Missing values in CurrentProfile which is 5.1% of total data
# 33 Missing values in MonthlyIncome which is 1.25% of total data

# %%
df_train_temp=df_train.copy()
df_test_temp=df_test.copy()

# %%
df_train['Gender'].dropna(inplace=True)
df_test['Gender'].dropna(inplace=True)

# %%
# Drop the datas which has missing values with < 3% in test and train
# WorkExperience 
# Age 
# Department 
# HomeToWork 
# WorkExperience 
# Designation 
# Gender - Drop

# %%
#Check for duplicate values
print('****Duplicates data in the train dataset without EmployeeID Column****')
print('**********************************************************************')

dups = df_train.loc[:, ~df_train.columns. isin(['EmployeeID'])].duplicated().sum()
if dups ==0:
    print('There is no duplicate values in the data.') 
else:
    print('There are {} duplicates in the data which is {}% of total data'.format(dups,round((dups/df_train.shape[0])*100,2)))
# Out:
# ****Duplicates data in the train dataset without EmployeeID Column****
# **********************************************************************
# There are 212 duplicates in the data which is 4.09% of total data

# %%
# #Check for duplicate values
# print('****Duplicates data in the test dataset without EmployeeID Column****')
# print('**********************************************************************')

# dups = df_test.loc[:, ~df_test.columns. isin(['EmployeeID'])].duplicated().sum()
# if dups ==0:
#     print('There is no duplicate values in the data.') 
# else:
#     print('There are {} duplicates in the data which is {}% of total data'.format(dups,round((dups/df_test.shape[0])*100,2)))

# %%
# df_train.drop('EmployeeID',axis=1,inplace=True)
# df_test.drop('EmployeeID',axis=1,inplace=True)

df_train.loc[:, ~df_train.columns. isin(['EmployeeID'])].drop_duplicates(inplace=True)
#df_test.loc[:, ~df_test.columns. isin(['EmployeeID'])].drop_duplicates(inplace=True)

# %%
print('****Describe the data - Continues Variables****')
print('***********************************************')
df_train.loc[:, ~df_train.columns. isin(['EmployeeID'])].describe().T
# Out:
# ****Describe the data - Continues Variables****
# ***********************************************
#                      count          mean          std     min      25%  \
# Attrition           5180.0      0.278958     0.448530     0.0      0.0
# Age                 4864.0     37.108553     9.248647    18.0     30.0
# HomeToWork          4925.0     11.107411     8.455577     1.0      5.0
# HourlnWeek          4893.0     57.979767    12.996674    10.0     49.0
# Involvement         5180.0      3.226641     0.872431     1.0      3.0
# WorkLifeBalance     5180.0      3.012741     1.410602     1.0      2.0
# JobSatisfaction     5180.0      3.144402     1.342776     1.0      2.0
# ESOPs               5180.0      0.490541     0.499959     0.0      0.0
# NumCompaniesWorked  5180.0      3.157336     2.606036     0.0      1.0
# OverTime            5180.0      0.313514     0.463966     0.0      0.0
# SalaryHikelastYear  5011.0     20.649371     3.706469    16.0     18.0
# ...

# %%
print('****Describe the data - Catagorical Variables****')
print('*************************************************')
print(df_train.describe(include='object').T)
# Out:
# ****Describe the data - Catagorical Variables****
# *************************************************
#                count unique         top  freq
# TravelProfile   5180      3      Rarely  3637
# Department      5056      3   Analytics  3219
# EducationField  5180      6  Statistics  2129
# Gender          5134      3        Male  3094
# Designation     5142      5   Executive  2072
# MaritalStatus   5180      4      Single  1776

# %%
cat=[]
num=[]
for i in df_train.loc[:, ~df_train.columns. isin(['EmployeeID'])]:
    if df_train[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
       
print('Catogorical Variables : \n*****************\n', cat) 
print('\nNumerical Variables : \n*****************\n', num)
# Out:
# Catogorical Variables :
# *****************
#  ['TravelProfile', 'Department', 'EducationField', 'Gender', 'Designation', 'MaritalStatus']
#
# Numerical Variables :
# *****************
#  ['Attrition', 'Age', 'HomeToWork', 'HourlnWeek', 'Involvement', 'WorkLifeBalance', 'JobSatisfaction', 'ESOPs', 'NumCompaniesWorked', 'OverTime', 'SalaryHikelastYear', 'WorkExperience', 'LastPromotion', 'CurrentProfile', 'MonthlyIncome']

# %%
#Unique values of the catagrical variables
for i in cat:
    print(f'Unique values of the catagorical variable {i}')
    print('*******************************************************\n')
    print(df_train[i].value_counts())
    print('\n')
# Out:
# Unique values of the catagorical variable TravelProfile
# *******************************************************
#
# Rarely    3637
# Yes       1051
# No         492
# Name: TravelProfile, dtype: int64
#
#
# Unique values of the catagorical variable Department
# *******************************************************
#
# Analytics    3219
# Sales        1615
# Marketing     222
# Name: Department, dtype: int64
#
#
# Unique values of the catagorical variable EducationField
# *******************************************************
#
# Statistics           2129
# CA                   1560
# Marketing Diploma     603
# Engineer              487
# Other                 284
# MBA                   117
# Name: EducationField, dtype: int64
#
#
# Unique values of the catagorical variable Gender
# *******************************************************
#
# Male      3094
# Female    1338
# F          702
# Name: Gender, dtype: int64
#
#
# Unique values of the catagorical variable Designation
# ...

# %%
#Unique values of the catagrical variables
for i in cat:
    print(f'Unique values of the catagorical variable {i}')
    print('*******************************************************\n')
    print(df_test[i].value_counts())
    print('\n')
# Out:
# Unique values of the catagorical variable TravelProfile
# *******************************************************
#
# Rarely    1852
# Yes        529
# No         249
# Name: TravelProfile, dtype: int64
#
#
# Unique values of the catagorical variable Department
# *******************************************************
#
# Analytics    1675
# Sales         792
# Marketing     105
# Name: Department, dtype: int64
#
#
# Unique values of the catagorical variable EducationField
# *******************************************************
#
# Statistics           1040
# CA                    857
# Marketing Diploma     291
# Engineer              263
# Other                 145
# MBA                    34
# Name: EducationField, dtype: int64
#
#
# Unique values of the catagorical variable Gender
# *******************************************************
#
# Male      1574
# Female     682
# F          344
# Name: Gender, dtype: int64
#
#
# Unique values of the catagorical variable Designation
# ...

# %% [markdown]
# * Marital status variable with value "M" needs to tagged with Married
# * Gender variable with "F" needs to tagged with Female variable

# %%
var = 'Gender'
df_train[var].replace('F','Female',inplace=True)
df_test[var].replace('F','Female',inplace=True)

print(f'Unique values of the catagorical variable {var}')
print('*******************************************************\n')
print(df_train[var].value_counts())
print('\n')

print(f'Unique values of the catagorical variable {var}')
print('*******************************************************\n')
print(df_test[var].value_counts())
# Out:
# Unique values of the catagorical variable Gender
# *******************************************************
#
# Male      3094
# Female    2040
# Name: Gender, dtype: int64
#
#
# Unique values of the catagorical variable Gender
# *******************************************************
#
# Male      1574
# Female    1026
# Name: Gender, dtype: int64

# %%
var = 'MaritalStatus'
df_train[var].replace('M','Married',inplace=True)
df_test[var].replace('M','Married',inplace=True)

print(f'Unique values of the catagorical variable {var}')
print('*******************************************************\n')
print(df_train[var].value_counts())
print('\n')

print(f'Unique values of the catagorical variable {var}')
print('*******************************************************\n')
print(df_test[var].value_counts())
# Out:
# Unique values of the catagorical variable MaritalStatus
# *******************************************************
#
# Married     2388
# Single      1776
# Divorsed    1016
# Name: MaritalStatus, dtype: int64
#
#
# Unique values of the catagorical variable MaritalStatus
# *******************************************************
#
# Married     1220
# Single       933
# Divorsed     477
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# * Unique values differnce are fixed

# %% [markdown]
# ###  Fixing Missing values in Age

# %%
nmstr=df_train['Age'].isnull().sum()
nmste=df_test['Age'].isnull().sum()
print(f'Number of missing values in Age: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Age:
#  Train	:	316
#  Test	:	142

# %%
#Fixing Missing values
df_train.groupby(by=['WorkExperience','EducationField'])['Age'].median()
# Out:
# WorkExperience  EducationField
# 0.0             CA                   18.0
#                 Marketing Diploma    18.0
#                 Statistics           18.0
# 1.0             CA                   22.0
#                 Engineer             20.0
#                                      ...
# 39.0            CA                   59.0
# 40.0            CA                   58.0
#                 Statistics           58.0
# 41.0            CA                   59.0
#                 Statistics           59.0
# Name: Age, Length: 202, dtype: float64

# %% [markdown]
# * Since "WorkExperience" and "EducationField" are the impacted value to identify the age. Gropping both and find the median can be identified, So this value can be impute the age will be meaning ful.

# %%
#Impute the Age with group by "WorkExprience" and "EductaionField"
df_train['Age'] = df_train['Age'].fillna(df_train.groupby(by=['WorkExperience','EducationField'])['Age'].transform('median'))
df_test['Age'] = df_test['Age'].fillna(df_test.groupby(by=['WorkExperience','EducationField'])['Age'].transform('median'))

# %%
nmstr=df_train['Age'].isnull().sum()
nmste=df_test['Age'].isnull().sum()
print(f'Number of missing values in Age: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Age:
#  Train	:	0
#  Test	:	0

# %% [markdown]
# * All the missing values are fixed in the Age Column

# %% [markdown]
# ### Fixing Missing values in Department

# %%
nmstr=df_train['Department'].isnull().sum()
nmste=df_test['Department'].isnull().sum()
print(f'Number of missing values in Department: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Department:
#  Train	:	124
#  Test	:	58

# %%
#Fixing Missing values
df_train.groupby('EducationField')['Department'].agg(pd.Series.mode)
# Out:
# EducationField
# CA                   Analytics
# Engineer             Analytics
# MBA                  Marketing
# Marketing Diploma        Sales
# Other                Analytics
# Statistics           Analytics
# Name: Department, dtype: object

# %%
#Impute the Department with mode value of group by "EductaionField"
df_train['Department'] = df_train.groupby(['EducationField'])['Department'].apply(lambda x: x.fillna(x.mode()[0]))
df_test['Department'] = df_test.groupby(['EducationField'])['Department'].apply(lambda x: x.fillna(x.mode()[0]))

# %% [markdown]
# * Department is more relavant to EductionField so filling the missing values with group by EducationField with mode value.

# %%
nmstr=df_train['Department'].isnull().sum()
nmste=df_test['Department'].isnull().sum()
print(f'Number of missing values in Department: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Department:
#  Train	:	0
#  Test	:	0

# %% [markdown]
# ### Fixing Missing values in HomeToWork

# %%
nmstr=df_train['HomeToWork'].isnull().sum()
nmste=df_test['HomeToWork'].isnull().sum()
print(f'Number of missing values in HomeToWork: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in HomeToWork:
#  Train	:	255
#  Test	:	126

# %%
df_train.groupby(by=['WorkLifeBalance','Gender'])['HomeToWork'].max()
# Out:
# WorkLifeBalance  Gender
# 1                Female     32.0
#                  Male       36.0
# 2                Female     32.0
#                  Male       32.0
# 3                Female     32.0
#                  Male      121.0
# 4                Female     32.0
#                  Male       36.0
# 5                Female     32.0
#                  Male       32.0
# Name: HomeToWork, dtype: float64

# %%
#Impute the HomeToWork with max value of group by "WorkLifeBalance","Gender"
df_train['HomeToWork'] = df_train['HomeToWork'].fillna(df_train.groupby(by=['WorkLifeBalance','Gender'])['HomeToWork'].transform('max'))
df_test['HomeToWork'] = df_test['HomeToWork'].fillna(df_test.groupby(by=['WorkLifeBalance','Gender'])['HomeToWork'].transform('max'))

# %%
nmstr=df_train['HomeToWork'].isnull().sum()
nmste=df_test['HomeToWork'].isnull().sum()
print(f'Number of missing values in HomeToWork: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in HomeToWork:
#  Train	:	0
#  Test	:	0

# %% [markdown]
# * Fixing Missing values in WorkExperience

# %%
nmstr=df_train['WorkExperience'].isnull().sum()
nmste=df_test['WorkExperience'].isnull().sum()
print(f'Number of missing values in WorkExperience: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in WorkExperience:
#  Train	:	187
#  Test	:	122

# %%
round(df_train.groupby(by=['Designation'])['WorkExperience'].mean(),0)
# Out:
# Designation
# AVP               26.0
# Executive          6.0
# Manager           11.0
# Senior Manager    15.0
# VP                27.0
# Name: WorkExperience, dtype: float64

# %%
df_train[df_train['WorkExperience'].isnull()]['Designation'].value_counts()
# Out:
# Manager           185
# Senior Manager      2
# Name: Designation, dtype: int64

# %%
df_train['WorkExperience'] = df_train.apply(
    lambda row: 11 if row['Designation']=='Manager' else row['WorkExperience'],
    axis=1
)

df_test['WorkExperience'] = df_test.apply(
    lambda row: 11 if row['Designation']=='Manager' else row['WorkExperience'],
    axis=1
)

df_train['WorkExperience'] = df_train.apply(
    lambda row: 15 if row['Designation']=='Senior Manager' else row['WorkExperience'],
    axis=1
)

df_test['WorkExperience'] = df_test.apply(
    lambda row: 15 if row['Designation']=='Senior Manager' else row['WorkExperience'],
    axis=1
)

# %%
nmstr=df_train['WorkExperience'].isnull().sum()
nmste=df_test['WorkExperience'].isnull().sum()
print(f'Number of missing values in WorkExperience: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in WorkExperience:
#  Train	:	0
#  Test	:	0

# %% [markdown]
# * Fixing Missing values in Designation

# %%
nmstr=df_train['Designation'].isnull().sum()
nmste=df_test['Designation'].isnull().sum()
print(f'Number of missing values in Designation: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Designation:
#  Train	:	38
#  Test	:	30

# %%
#Fixing Missing values
df_train.groupby('WorkExperience')['Designation'].agg(pd.Series.mode)
# Out:
# WorkExperience
# 0.0          Executive
# 1.0          Executive
# 2.0          Executive
# 3.0          Executive
# 4.0          Executive
# 5.0          Executive
# 6.0          Executive
# 7.0          Executive
# 8.0          Executive
# 9.0          Executive
# 10.0         Executive
# 11.0           Manager
# 12.0         Executive
# 13.0         Executive
# 14.0         Executive
# 15.0    Senior Manager
# 16.0         Executive
# 17.0         Executive
# 18.0         Executive
# 19.0         Executive
# 20.0         Executive
# 21.0               AVP
# 22.0               AVP
# 23.0               AVP
# 24.0                VP
# 25.0               AVP
# 26.0               AVP
# 27.0               AVP
# 28.0               AVP
# 29.0               AVP
# 30.0               AVP
# 31.0               AVP
# 32.0               AVP
# 33.0                VP
# 34.0                VP
# 35.0         [AVP, VP]
# 36.0                VP
# 37.0               AVP
# 38.0               AVP
# ...

# %%
#Impute the Department with mode value of group by "EductaionField"
df_train['Designation'] = df_train.groupby(['WorkExperience'])['Designation'].apply(lambda x: x.fillna(x.mode()[0]))
df_test['Designation'] = df_test.groupby(['WorkExperience'])['Designation'].apply(lambda x: x.fillna(x.mode()[0]))

# %%
nmstr=df_train['Designation'].isnull().sum()
nmste=df_test['Designation'].isnull().sum()
print(f'Number of missing values in Designation: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Designation:
#  Train	:	0
#  Test	:	0

# %%
nmstr=df_train['Gender'].isnull().sum()
nmste=df_test['Gender'].isnull().sum()
print(f'Number of missing values in Gender: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Gender:
#  Train	:	46
#  Test	:	30

# %%
#Impute the Department with mode value of group by "EductaionField"
df_train['Gender'].fillna(df_train['Gender'].mode()[0],inplace=True)
df_test['Gender'].fillna(df_test['Gender'].mode()[0],inplace=True)

# %%
nmstr=df_train['Gender'].isnull().sum()
nmste=df_test['Gender'].isnull().sum()
print(f'Number of missing values in Gender: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in Gender:
#  Train	:	0
#  Test	:	0

# %%
nmstr=df_train['HourlnWeek'].isnull().sum()
nmste=df_test['HourlnWeek'].isnull().sum()
print(f'Number of missing values in HourlnWeek: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in HourlnWeek:
#  Train	:	287
#  Test	:	136

# %%
#Fixing Missing values
df_train.groupby(by=['Age','MaritalStatus','Gender'])['HourlnWeek'].median()
# Out:
# Age   MaritalStatus  Gender
# 18.0  Single         Female    69.0
#                      Male      69.0
# 19.0  Single         Female    67.5
#                      Male      50.0
# 20.0  Married        Female    61.0
#                                ...
# 60.0  Single         Male      54.0
# 61.0  Divorsed       Female    62.5
#       Married        Female    43.0
#                      Male      59.0
#       Single         Male      56.0
# Name: HourlnWeek, Length: 251, dtype: float64

# %%
#Fixing Missing values
df_test.groupby(by=['Age','MaritalStatus','Gender'])['HourlnWeek'].median()
# Out:
# Age   MaritalStatus  Gender
# 18.0  Single         Female    68.0
#                      Male      69.0
# 19.0  Married        Female    61.0
#       Single         Female    69.0
#                      Male      52.0
#                                ...
# 60.0  Divorsed       Male      70.0
#       Married        Male      68.0
#       Single         Female    75.5
# 61.0  Married        Female    82.0
#                      Male      59.0
# Name: HourlnWeek, Length: 242, dtype: float64

# %%
#Impute the HomeToWork with max value of group by "WorkLifeBalance","Gender"
df_train['HourlnWeek'] = df_train['HourlnWeek'].fillna(df_train.groupby(by=['Age','MaritalStatus','Gender'])['HourlnWeek'].transform('median'))
df_test['HourlnWeek'] = df_test['HourlnWeek'].fillna(df_test.groupby(by=['Age','MaritalStatus','Gender'])['HourlnWeek'].transform('median'))

# %%
df_test['HourlnWeek'].fillna(60,inplace=True)

# %%
nmstr=df_train['HourlnWeek'].isnull().sum()
nmste=df_test['HourlnWeek'].isnull().sum()
print(f'Number of missing values in HourlnWeek: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in HourlnWeek:
#  Train	:	0
#  Test	:	0

# %%
nmstr=df_train['MonthlyIncome'].isnull().sum()
nmste=df_test['MonthlyIncome'].isnull().sum()
print(f'Number of missing values in MonthlyIncome: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in MonthlyIncome:
#  Train	:	93
#  Test	:	33

# %%
#Fixing Missing values
df_test.groupby(by=['Designation','WorkExperience'])['MonthlyIncome'].median()
# Out:
# Designation  WorkExperience
# AVP          9.0               31422.0
#              10.0              32124.0
#              11.0              33444.0
#              16.0              32007.0
#              17.0              31992.0
#                                 ...
# VP           35.0              34837.0
#              36.0              34586.0
#              37.0              34722.0
#              40.0              34246.0
#              41.0              35246.0
# Name: MonthlyIncome, Length: 66, dtype: float64

# %%
#Impute the HomeToWork with max value of group by "WorkLifeBalance","Gender"
df_train['MonthlyIncome'] = df_train['MonthlyIncome'].fillna(df_train.groupby(by=['Designation','WorkExperience'])['MonthlyIncome'].transform('median'))
df_test['MonthlyIncome'] = df_test['MonthlyIncome'].fillna(df_test.groupby(by=['Designation','WorkExperience'])['MonthlyIncome'].transform('median'))

# %%
nmstr=df_train['MonthlyIncome'].isnull().sum()
nmste=df_test['MonthlyIncome'].isnull().sum()
print(f'Number of missing values in MonthlyIncome: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in MonthlyIncome:
#  Train	:	0
#  Test	:	0

# %%
nmstr=df_train['SalaryHikelastYear'].isnull().sum()
nmste=df_test['SalaryHikelastYear'].isnull().sum()
print(f'Number of missing values in SalaryHikelastYear: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in SalaryHikelastYear:
#  Train	:	169
#  Test	:	94

# %%
#Fixing Missing values
df_test.groupby(by=['Designation','WorkExperience'])['SalaryHikelastYear'].median()
# Out:
# Designation  WorkExperience
# AVP          9.0               16.0
#              10.0              20.0
#              11.0              17.0
#              16.0              19.0
#              17.0              20.0
#                                ...
# VP           35.0              20.5
#              36.0              19.0
#              37.0              19.0
#              40.0              17.0
#              41.0              18.0
# Name: SalaryHikelastYear, Length: 66, dtype: float64

# %%
#Impute the HomeToWork with max value of group by "WorkLifeBalance","Gender"
df_train['SalaryHikelastYear'] = df_train['SalaryHikelastYear'].fillna(df_train.groupby(by=['Designation','WorkExperience'])['SalaryHikelastYear'].transform('median'))
df_test['SalaryHikelastYear'] = df_test['SalaryHikelastYear'].fillna(df_test.groupby(by=['Designation','WorkExperience'])['SalaryHikelastYear'].transform('median'))

# %%
nmstr=df_train['SalaryHikelastYear'].isnull().sum()
nmste=df_test['SalaryHikelastYear'].isnull().sum()
print(f'Number of missing values in SalaryHikelastYear: \n Train\t:\t{nmstr}\n Test\t:\t{nmste}')
# Out:
# Number of missing values in SalaryHikelastYear:
#  Train	:	0
#  Test	:	0

# %%
df_train['LastPromotion'].fillna(0,inplace=True)
df_test['LastPromotion'].fillna(0,inplace=True)

# %%
df_train['CurrentProfile'].fillna(8,inplace=True)
df_test['CurrentProfile'].fillna(8,inplace=True)

# %%
df_train_ana  = df_train.copy()

# %%
df_train_ana.isnull().sum()
# Out:
# EmployeeID            0
# Attrition             0
# Age                   0
# TravelProfile         0
# Department            0
# HomeToWork            0
# EducationField        0
# Gender                0
# HourlnWeek            0
# Involvement           0
# WorkLifeBalance       0
# Designation           0
# JobSatisfaction       0
# ESOPs                 0
# NumCompaniesWorked    0
# OverTime              0
# SalaryHikelastYear    0
# WorkExperience        0
# LastPromotion         0
# CurrentProfile        0
# MaritalStatus         0
# MonthlyIncome         0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# EmployeeID            0
# Age                   0
# TravelProfile         0
# Department            0
# HomeToWork            0
# EducationField        0
# Gender                0
# HourlnWeek            0
# Involvement           0
# WorkLifeBalance       0
# Designation           0
# JobSatisfaction       0
# ESOPs                 0
# NumCompaniesWorked    0
# OverTime              0
# SalaryHikelastYear    0
# WorkExperience        0
# LastPromotion         0
# CurrentProfile        0
# MaritalStatus         0
# MonthlyIncome         0
# dtype: int64

# %%
bins = [17,30,45,65]
labels=['17-30','31-45','46-65']

df_train_ana['AgeRange'] = pd.cut(df_train_ana['Age'],bins=bins, labels=labels)

# %%
bins = [0,25,50,75,100,np.inf]
labels=['0-25','26-50','51-75','76-100','>100']
df_train_ana['HomeToWorkRange'] = pd.cut(df_train_ana['HomeToWork'],bins=bins, labels=labels)

# %%
bins = [1,20,50,75,100]
labels=['<20','21-50','51-75','76-100']

df_train_ana['HourlnWeekRange'] = pd.cut(df_train_ana['HourlnWeek'],bins=bins, labels=labels)

# %%
bins = [-1,5,10,15,25]
labels=['0-5','6-10','11-15','16-25']

df_train_ana['NumCompaniesWorkedRange'] = pd.cut(df_train_ana['NumCompaniesWorked'],bins=bins, labels=labels)

# %%
bins = [15,25,35]
labels=['15-25','26-35']

df_train_ana['SalaryHikelastYearRange'] = pd.cut(df_train_ana['SalaryHikelastYear'],bins=bins, labels=labels)

# %%
bins = [-1,10,20,30,40,41]
labels=['0-10','11-20','21-30','31-40','>40']

df_train_ana['WorkExperienceRange'] = pd.cut(df_train_ana['WorkExperience'],bins=bins, labels=labels)

# %%
bins = [-1,5,10,15,20]
labels=['0-5','6-10','11-15','>15']

df_train_ana['LastPromotionRange'] = pd.cut(df_train_ana['LastPromotion'],bins=bins, labels=labels)

# %%
numrange = ['AgeRange','HomeToWorkRange','HourlnWeekRange','NumCompaniesWorkedRange','SalaryHikelastYearRange','WorkExperienceRange','LastPromotionRange']

# %%
fig, axis=plt.subplots(nrows=16,ncols=2)
fig.set_size_inches(15,17)
fig.tight_layout()

i=0
for cols in num:
    sns.distplot(df_train_ana[cols],ax=axis[i][0]);
    sns.boxplot(df_train_ana[cols],ax=axis[i][1]);
    i=i+1

# %%
#Define the function to identify the outliers
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
#Fix the outliers 
columns = ['Age','NumCompaniesWorked','WorkExperience','LastPromotion','MonthlyIncome']
for column in columns:
    lr,ur=remove_outlier(df_train[column])
    df_train[column]=np.where(df_train[column]>ur,ur,df_train[column])
    df_train[column]=np.where(df_train[column]<lr,lr,df_train[column])

    df_train_ana[column]=np.where(df_train_ana[column]>ur,ur,df_train_ana[column])
    df_train_ana[column]=np.where(df_train_ana[column]<lr,lr,df_train_ana[column])

# %%
fig, axis=plt.subplots(nrows=5,ncols=1)
fig.set_size_inches(10,10)
fig.tight_layout()

i=0
for cols in columns:
    sns.boxplot(df_train[cols],ax=axis[i]);
    i=i+1

# %%
tvar='Attrition'

# %%
tvar='Attrition'
fig, axis=plt.subplots(nrows=7,ncols=3)
fig.set_size_inches(17,25)
fig.tight_layout()

i=0
for cols in numrange:
    sns.countplot(x=df_train_ana[cols],hue=df_train['TravelProfile'],ax=axis[i][0]);
    sns.countplot(x=df_train_ana[cols],hue=df_train['Gender'],ax=axis[i][1]);
    sns.countplot(x=df_train_ana[cols],hue=df_train['MaritalStatus'],ax=axis[i][2]);
    i=i+1

# %%
tvar='Attrition'
fig, axis=plt.subplots(nrows=7,ncols=3)
fig.set_size_inches(17,25)
fig.tight_layout()

i=0
for cols in numrange:
    sns.countplot(x=df_train_ana[cols],hue=df_train['EducationField'],ax=axis[i][0]);
    sns.countplot(x=df_train_ana[cols],hue=df_train['Department'],ax=axis[i][1]);
    sns.countplot(x=df_train_ana[cols],hue=df_train['Designation'],ax=axis[i][2]);
    i=i+1

# %%
tvar='Attrition'
fig, axis=plt.subplots(nrows=7,ncols=1)
fig.set_size_inches(10,20)
fig.tight_layout()

i=0
for cols in numrange:
    sns.countplot(x=df_train_ana[cols],hue=df_train[tvar],ax=axis[i]);
#    sns.stripplot(x=df_train[cols],y=df_train[tvar],ax=axis[i]);
    i=i+1

# %%
colsana = ['Involvement','WorkLifeBalance','JobSatisfaction','ESOPs','OverTime','CurrentProfile']
tvar='Attrition'
fig, axis=plt.subplots(nrows=6,ncols=1)
fig.set_size_inches(10,20)
fig.tight_layout()

i=0
for cols in colsana:
    sns.countplot(x=df_train_ana[cols],hue=df_train_ana[tvar],ax=axis[i]);
#    sns.stripplot(y=df_train[cols],x=df_train[tvar],ax=axis[i]);
    i=i+1

# %%
# for col in df_train.columns:
#     if df_train[col].dtype!="object":
#         df_train[col] = df_train[col].astype('category',copy=False)

# %%
#Heat map - Relationalship analysis
plt.figure(figsize=(15,10))
sns.heatmap(df_train.corr(),annot=True,mask=np.triu(df_train.corr(),+1));

# %%
for feature in df_train.columns: 
    if df_train[feature].dtype == 'object': 
        df_train[feature] = pd.Categorical(df_train[feature]).codes

        
for feature in df_test.columns: 
    if df_test[feature].dtype == 'object': 
        df_test[feature] = pd.Categorical(df_test[feature]).codes

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.metrics import roc_auc_score,roc_curve,plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
X = df_train.drop(['EmployeeID',tvar], axis=1)
y = df_train[tvar]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.30,random_state=0)

# %%
X_train.shape
# Out:
# (3626, 20)

# %%
X_test.shape
# Out:
# (1554, 20)

# %%
#Scale the data using feature scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
sc_train = scaler.fit_transform(X_train)
X_train_sc = pd.DataFrame(sc_train, index=X_train.index, columns=X_train.columns)

# %%
sc_test = scaler.transform(X_test)
X_test_sc = pd.DataFrame(sc_test, index=X_test.index, columns=X_test.columns)

# %%
def display_dataframe(df):
    numeric_col_mask = df.dtypes.apply(lambda d: issubclass(np.dtype(d).type, np.number))

    # Dict used to center the table headers
    d = dict(selector="th",
        props=[('text-align', 'center')])

    # Style
    display(df.style.set_properties(subset=df.columns[numeric_col_mask], # right-align the numeric columns and set their width
                            **{'width':'5em', 'height':'3em','text-align':'right','border-color': 'white','border-style' :'solid'})\
            .set_properties(subset=df.columns[~numeric_col_mask], # left-align the non-numeric columns and set their width
                            **{'width':'5em', 'text-align':'left'})\
            .format(lambda x: '{:,.0f}'.format(x) if x > 1e3 else '{:,.2f}'.format(x), # format the numeric values
                    subset=pd.IndexSlice[:,df.columns[numeric_col_mask]])\
            .hide_index()\
#            .highlight_max('color: green')\
            .set_table_styles([d])) # center the header

# %%
#AUC and ROC Value
def roc_model(model_name,x,y):
    # predict probabilities
    probs = model_name.predict_proba(x)
    # keep probabilities for the positive outcome only
    probs = probs[:, 1]
    # calculate AUC
    from sklearn.metrics import roc_auc_score
    auc = roc_auc_score(y, probs)
    fpr, tpr, _ = roc_curve(y, probs)
    return probs,auc,fpr,tpr

# %%
def con_mat(y_train,y_predict_train,y_test,y_predict_test):
    fig, axis=plt.subplots(nrows=1,ncols=2)
    fig.set_size_inches(10,4)
    fig.tight_layout()

    cm=confusion_matrix(y_train,y_predict_train,labels=[0, 1])

    df_cm = pd.DataFrame(cm, index = [i for i in ["Conservative","Labour"]],
    columns = [i for i in ["Conservative","Labour"]])
    sns.heatmap(df_cm, annot=True ,fmt='g',ax=axis[0])
    axis[0].title.set_text('Confustion Matrix - Train Data')

    cm=confusion_matrix(y_test,y_predict_test,labels=[0, 1])

    df_cm = pd.DataFrame(cm, index = [i for i in ["Conservative","Labour"]],
    columns = [i for i in ["Conservative","Labour"]])
    sns.heatmap(df_cm, annot=True ,fmt='g',ax=axis[1])
    axis[1].title.set_text('Confustion Matrix - Test Data')

# %%
def scores_train_test(model,X_train,X_test,y_train,y_test,y_predict_train,y_predict_test,mname):
    #model=bgcl
    from IPython.display import HTML 
    from sklearn.metrics import precision_recall_fscore_support as score

    s = [[None for j in range(6)] for i in range(2)]

    print(str(model).split('(')[0])
    print('********************************\n')

    model_name = str(model).split('(')[0]
    s[0][0] = model_name + '_' + mname +'_Train'
    s[1][0] = model_name + '_' + mname +'_Test'

    for prf in range(1,4):
        s[0][prf]=round(score(y_train,y_predict_train)[prf-1][1]*100,2)
        s[1][prf]= (round(score(y_test,y_predict_test)[prf-1][1]*100,2))

    s[0][prf+1]=round(model.score(X_train,y_train)*100,2)
    s[1][prf+1]=round(model.score(X_test,y_test)*100,2)    

    probs, auc, fpr, tpr = roc_model(model,X_train,y_train)
    probst, auc1, fpr1, tpr1 = roc_model(model,X_test,y_test)

    s[0][prf+2]=round(auc*100,2)
    s[1][prf+2]=round(auc1*100,2)

    df = pd.DataFrame(data=s,columns=['Scores','Precision','Recall','F-Score','Accuracy','AUC'])

    con_mat(y_train,y_predict_train,y_test,y_predict_test)

    plt.figure(figsize=(5,5))

    plt.plot(fpr,tpr, marker='o', label='AUC - Train:' + str(s[0][prf+2]))
    plt.plot(fpr1,tpr1, marker='o', label='AUC - Test:' + str(s[1][prf+2]))

    plt.legend(loc="lower right")
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC')

    print('Display Metrics of Train and Test Data')
    print('***************************************')

    display_dataframe(df)
    return(df)

# %%
#Logistic Regression with GridSearc CV
def lgrun(x_train,train_labels,x_test,tol,max_iter,n_jobs,sol,C,penality,sco):
    param_grid = {
        'penalty': penality,
        'C':C,
        'max_iter':max_iter,
        'solver':sol,
        'n_jobs':n_jobs,
        'tol':tol
    },


    clf = LogisticRegression(random_state=0)

    grid_clf_acc = GridSearchCV(clf, param_grid = param_grid,scoring = sco,cv=5)
    grid_clf_acc.fit(x_train, train_labels)
    lgr_model=grid_clf_acc.best_estimator_
    print(grid_clf_acc.best_params_)    
    lgr_model
    lgr_train=lgr_model.predict(x_train)
    lgr_test=lgr_model.predict(x_test)

    return(lgr_model,lgr_train,lgr_test)

# %%
#LDA with GridSearc CV
def ldarun(x_train,train_labels,x_test,tol,n_jobs,sol,sco):
    param_grid = {
        'solver':sol,
        'tol':tol
    },
    
    clf = LinearDiscriminantAnalysis()

    grid_clf_acc = GridSearchCV(clf, param_grid = param_grid, cv=5,
                      scoring=sco,n_jobs=n_jobs ,verbose = 1)
                                
    grid_clf_acc.fit(x_train, train_labels)
    lda_model=grid_clf_acc.best_estimator_
    print(grid_clf_acc.best_params_)    
    lda_train=lgr_model.predict(x_train)
    lda_test=lgr_model.predict(x_test)
    return(lda_model,lda_train,lda_test)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = [variance_inflation_factor(X.values, ix) for ix in range(X.shape[1])] 
i=0
for column in X.columns:
        if vif[i] <= 1:
            corrange='Not'
        elif vif[i] >1 and vif[i] <6:
            corrange ='Moderately'
        else:
            corrange ='Highly'
        print(f"Column {column} --> VIF : {round(vif[i],2)} and {corrange} correlated")
        i=i+1
# Out:
# Column Age --> VIF : 26.95 and Highly correlated
# Column TravelProfile --> VIF : 5.13 and Moderately correlated
# Column Department --> VIF : 1.59 and Moderately correlated
# Column HomeToWork --> VIF : 2.13 and Moderately correlated
# Column EducationField --> VIF : 2.62 and Moderately correlated
# Column Gender --> VIF : 2.52 and Moderately correlated
# Column HourlnWeek --> VIF : 19.61 and Highly correlated
# Column Involvement --> VIF : 14.02 and Highly correlated
# Column WorkLifeBalance --> VIF : 5.45 and Moderately correlated
# Column Designation --> VIF : 5.32 and Moderately correlated
# Column JobSatisfaction --> VIF : 6.28 and Highly correlated
# Column ESOPs --> VIF : 1.96 and Moderately correlated
# Column NumCompaniesWorked --> VIF : 2.92 and Moderately correlated
# Column OverTime --> VIF : 1.48 and Moderately correlated
# Column SalaryHikelastYear --> VIF : 26.78 and Highly correlated
# Column WorkExperience --> VIF : 16.17 and Highly correlated
# ...

# %%
#Logistic Regression - Scaled data.
lgr_model = LogisticRegression(random_state=0)
lgr_model.fit(X_train_sc,y_train)

lgr_train=lgr_model.predict(X_train_sc)
lgr_test=lgr_model.predict(X_test_sc)

# %%
X_train.columns
# Out:
# Index(['Age', 'TravelProfile', 'Department', 'HomeToWork', 'EducationField',
#        'Gender', 'HourlnWeek', 'Involvement', 'WorkLifeBalance', 'Designation',
#        'JobSatisfaction', 'ESOPs', 'NumCompaniesWorked', 'OverTime',
#        'SalaryHikelastYear', 'WorkExperience', 'LastPromotion',
#        'CurrentProfile', 'MaritalStatus', 'MonthlyIncome'],
#       dtype='object')

# %%
print('intercept:', lgr_model.intercept_)
print('coefficient:', lgr_model.coef_[0])
# Out:
# intercept: [-1.33565965]
# coefficient: [-0.22464613  0.38503821  0.31442213  0.21614835 -0.06609219  0.14530826
#   0.02197518  0.3488271   0.0515876   0.04691625  0.43666484  0.05158514
#   0.35324401  0.68274153 -0.04897388 -0.45558583  0.35209879 -0.32895739
#   0.43047127 -0.32545078]

# %%
res_df = scores_train_test(lgr_model,X_train_sc,X_test_sc,y_train,y_test,lgr_train,lgr_test,'Base')
# Out:
# LogisticRegression
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_f2456_ th {
#           text-align: center;
#     }#T_f2456_row0_col0,#T_f2456_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_f2456_row0_col1,#T_f2456_row0_col2,#T_f2456_row0_col3,#T_f2456_row0_col4,#T_f2456_row0_col5,#T_f2456_row1_col1,#T_f2456_row1_col2,#T_f2456_row1_col3,#T_f2456_row1_col4,#T_f2456_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf=res_df.copy()

# %%
clf = LinearDiscriminantAnalysis()
lda_model=clf.fit(X_train_sc, y_train)

lda_model_ytrain_predict = lda_model.predict(X_train_sc)
lda_model_ytest_predict = lda_model.predict(X_test_sc)

# %%
print('intercept:', lda_model.intercept_)
print('coefficient:', lda_model.coef_[0])
# Out:
# intercept: [-1.30470024]
# coefficient: [-0.22828644  0.38331725  0.29838598  0.22124454 -0.07403401  0.13593731
#  -0.0035905   0.34768705  0.04364655 -0.03040691  0.44223408  0.03640982
#   0.32485748  0.76312578 -0.04490973 -0.43333143  0.29175266 -0.30536586
#   0.43988885 -0.13716235]

# %%
res_df=scores_train_test(clf,X_train_sc,X_test_sc,y_train,y_test,
                         lda_model_ytrain_predict,lda_model_ytest_predict,'Base')
# Out:
# LinearDiscriminantAnalysis
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_b7112_ th {
#           text-align: center;
#     }#T_b7112_row0_col0,#T_b7112_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_b7112_row0_col1,#T_b7112_row0_col2,#T_b7112_row0_col3,#T_b7112_row0_col4,#T_b7112_row0_col5,#T_b7112_row1_col1,#T_b7112_row1_col2,#T_b7112_row1_col3,#T_b7112_row1_col4,#T_b7112_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %%
rfcl = RandomForestClassifier(random_state=0)

rfcl.fit(X_train, y_train)
rf_train = rfcl.predict(X_train)
rf_test = rfcl.predict(X_test)

# %%
res_df = scores_train_test(rfcl,X_train,X_test,y_train,y_test,rf_train,rf_test,'Base')
# Out:
# RandomForestClassifier
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_39bbe_ th {
#           text-align: center;
#     }#T_39bbe_row0_col0,#T_39bbe_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_39bbe_row0_col1,#T_39bbe_row0_col2,#T_39bbe_row0_col3,#T_39bbe_row0_col4,#T_39bbe_row0_col5,#T_39bbe_row1_col1,#T_39bbe_row1_col2,#T_39bbe_row1_col3,#T_39bbe_row1_col4,#T_39bbe_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %% [markdown]
# 1.5) Apply KNN Model and Naïve Bayes Model(5 pts). Interpret the inferences of each model (2 pts)

# %%
#Base model with K-Value as 5
KNN_Model = KNeighborsClassifier(n_neighbors=5)
KNN_Model.fit(X_train_sc,y_train)
KNN_train_p = KNN_Model.predict(X_train_sc)
KNN_test_p = KNN_Model.predict(X_test_sc)

# %%
print(f'Accuracy Score for K={5} : ',KNN_Model.score(X_test_sc,y_test))
# Out:
# Accuracy Score for K=5 :  0.9066924066924067

# %%
res_df=scores_train_test(KNN_Model,X_train_sc,X_test_sc,y_train,y_test,KNN_train_p,KNN_test_p,'Base')
# Out:
# KNeighborsClassifier
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_f31b9_ th {
#           text-align: center;
#     }#T_f31b9_row0_col0,#T_f31b9_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_f31b9_row0_col1,#T_f31b9_row0_col2,#T_f31b9_row0_col3,#T_f31b9_row0_col4,#T_f31b9_row0_col5,#T_f31b9_row1_col1,#T_f31b9_row1_col2,#T_f31b9_row1_col3,#T_f31b9_row1_col4,#T_f31b9_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %%
NB_model = GaussianNB()
NB_model.fit(X_train, y_train)
NB_Model_y_predict_train = NB_model.predict(X_train)
NB_Model_y_predict_test = NB_model.predict(X_test)

# %%
res_df=scores_train_test(NB_model,X_train,X_test,y_train,y_test,NB_Model_y_predict_train,NB_Model_y_predict_test,'Base')
# Out:
# GaussianNB
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_10991_ th {
#           text-align: center;
#     }#T_10991_row0_col0,#T_10991_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_10991_row0_col1,#T_10991_row0_col2,#T_10991_row0_col3,#T_10991_row0_col4,#T_10991_row0_col5,#T_10991_row1_col1,#T_10991_row1_col2,#T_10991_row1_col3,#T_10991_row1_col4,#T_10991_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %%
tempdf
# Out:
#                                   Scores  Precision  Recall  F-Score  \
# 0          LogisticRegression_Base_Train      72.35   49.46    58.76
# 1           LogisticRegression_Base_Test      69.26   50.47    58.39
# 0  LinearDiscriminantAnalysis_Base_Train      70.85   49.27    58.12
# 1   LinearDiscriminantAnalysis_Base_Test      70.36   50.94    59.10
# 0      RandomForestClassifier_Base_Train     100.00  100.00   100.00
# 1       RandomForestClassifier_Base_Test      97.62   96.93    97.28
# 0        KNeighborsClassifier_Base_Train      91.86   95.00    93.40
# 1         KNeighborsClassifier_Base_Test      81.49   85.14    83.28
# 0                  GaussianNB_Base_Train      54.91   66.21    60.04
# 1                   GaussianNB_Base_Test      56.67   65.09    60.59
#
#    Accuracy     AUC
# 0     80.45   81.96
# 1     80.37   81.05
# 0     80.01   81.76
# 1     80.76   81.18
# 0    100.00  100.00
# 1     98.52   99.72
# 0     96.22   99.11
# 1     90.67   96.36
# ...

# %%
#siva

# %% [markdown]
# 1.6) Model Tuning, Bagging and Boosting.

# %% [markdown]
# Model Tuning - Logistic Regression

# %%
penalty=['none','11','l2',]
solver=['newton-cg','liblinear']#,,'lbfgs','sag','liblinear','saga']
tol=[0.0001]#,0.0001,0.00001]
C =[0.1,0.01,1.0]
maxit = [10000,5000]
njobs = [7,15]

lgr_model,lgr_train,lgr_test = lgrun(X_train_sc,y_train,X_test_sc,tol,maxit,njobs,solver,C,penalty,'accuracy')
# Out:
# {'C': 0.01, 'max_iter': 10000, 'n_jobs': 7, 'penalty': 'l2', 'solver': 'newton-cg', 'tol': 0.0001}

# %%
res_df = scores_train_test(lgr_model,X_train_sc,X_test_sc,y_train,y_test,lgr_train,lgr_test,'Tuned')
# Out:
# LogisticRegression
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_b7831_ th {
#           text-align: center;
#     }#T_b7831_row0_col0,#T_b7831_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_b7831_row0_col1,#T_b7831_row0_col2,#T_b7831_row0_col3,#T_b7831_row0_col4,#T_b7831_row0_col5,#T_b7831_row1_col1,#T_b7831_row1_col2,#T_b7831_row1_col3,#T_b7831_row1_col4,#T_b7831_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %%
# Training Data Probability Prediction
pred_prob_train = lgr_model.predict_proba(X_train_sc)

# Test Data Probability Prediction
pred_prob_test = lgr_model.predict_proba(X_test_sc)

# %%
for j in np.arange(0.1,1,0.1):
    custom_prob = j #defining the cut-off value of our choice
    custom_cutoff_data=[]#defining an empty list
    for i in range(0,len(y_train)):#defining a loop for the length of the test data
        if np.array(pred_prob_train[:,1])[i] > custom_prob:#issuing a condition for our probability values to be 
            #greater than the custom cutoff value
            a=1#if the probability values are greater than the custom cutoff then the value should be 1
        else:
            a=0#if the probability values are less than the custom cutoff then the value should be 0
        custom_cutoff_data.append(a)#adding either 1 or 0 based on the condition to the end of the list defined by us
    print(round(j,3),'\n')
    print('Accuracy Score',round(metrics.accuracy_score(y_train,custom_cutoff_data),4))
    print('F1 Score',round(metrics.f1_score(y_train,custom_cutoff_data),4),'\n')
    plt.figure(figsize=(6,4))
    print('Confusion Matrix')
    sns.heatmap(metrics.confusion_matrix(y_train,custom_cutoff_data),annot=True,fmt='.4g'),'\n\n'
    plt.show();
# Out:
# 0.1
#
# Accuracy Score 0.4708
# F1 Score 0.5063
#
# Confusion Matrix
# 0.2
#
# Accuracy Score 0.6351
# F1 Score 0.5641
#
# Confusion Matrix
# 0.3
#
# Accuracy Score 0.7504
# F1 Score 0.6274
#
# Confusion Matrix
# 0.4
#
# Accuracy Score 0.7915
# F1 Score 0.6166
#
# Confusion Matrix
# 0.5
#
# Accuracy Score 0.8125
# F1 Score 0.5787
#
# Confusion Matrix
# 0.6
#
# Accuracy Score 0.7915
# F1 Score 0.4449
#
# Confusion Matrix
# 0.7
#
# Accuracy Score 0.7557
# F1 Score 0.2592
#
# Confusion Matrix
# 0.8
#
# Accuracy Score 0.7369
# F1 Score 0.1311
#
# Confusion Matrix
# 0.9
#
# Accuracy Score 0.7195
# F1 Score 0.0078
#
# Confusion Matrix

# %%
data_pred_custom_cutoff=[]
for i in range(0,len(pred_prob_test[:,1])):
    if np.array(pred_prob_test[:,1])[i]>0.4:
        a=1
    else:
        a=0
    data_pred_custom_cutoff.append(a)
sns.heatmap((metrics.confusion_matrix(y_test,data_pred_custom_cutoff)),annot=True,fmt='.4g');

# %% [markdown]
# Model Tuning - LinearDiscriminantAnalysis

# %%
solver=['svd','eigen']
tol=[0.0001]#,0.0001,0.00001]
n_jobs = 4

lda_model,lda_model_ytrain_predict,lda_model_ytest_predict = ldarun(X_train_sc,y_train,X_test_sc,tol,n_jobs,solver,'accuracy')
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# {'solver': 'svd', 'tol': 0.0001}

# %%
res_df=scores_train_test(clf,X_train_sc,X_test_sc,y_train,y_test,
                         lda_model_ytrain_predict,lda_model_ytest_predict,'Tuned')
# Out:
# LinearDiscriminantAnalysis
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_6ccdb_ th {
#           text-align: center;
#     }#T_6ccdb_row0_col0,#T_6ccdb_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_6ccdb_row0_col1,#T_6ccdb_row0_col2,#T_6ccdb_row0_col3,#T_6ccdb_row0_col4,#T_6ccdb_row0_col5,#T_6ccdb_row1_col1,#T_6ccdb_row1_col2,#T_6ccdb_row1_col3,#T_6ccdb_row1_col4,#T_6ccdb_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
# Training Data Probability Prediction
pred_prob_train = lda_model.predict_proba(X_train_sc)

# Test Data Probability Prediction
pred_prob_test = lda_model.predict_proba(X_test_sc)

# %%
for j in np.arange(0.1,1,0.1):
    custom_prob = j #defining the cut-off value of our choice
    custom_cutoff_data=[]#defining an empty list
    for i in range(0,len(y_train)):#defining a loop for the length of the test data
        if np.array(pred_prob_train[:,1])[i] > custom_prob:#issuing a condition for our probability values to be 
            #greater than the custom cutoff value
            a=1#if the probability values are greater than the custom cutoff then the value should be 1
        else:
            a=0#if the probability values are less than the custom cutoff then the value should be 0
        custom_cutoff_data.append(a)#adding either 1 or 0 based on the condition to the end of the list defined by us
    print(round(j,3),'\n')
    print('Accuracy Score',round(metrics.accuracy_score(y_train,custom_cutoff_data),4))
    print('F1 Score',round(metrics.f1_score(y_train,custom_cutoff_data),4),'\n')
    plt.figure(figsize=(6,4))
    print('Confusion Matrix')
    sns.heatmap(metrics.confusion_matrix(y_train,custom_cutoff_data),annot=True,fmt='.4g'),'\n\n'
    plt.show();
# Out:
# 0.1
#
# Accuracy Score 0.5259
# F1 Score 0.5261
#
# Confusion Matrix
# 0.2
#
# Accuracy Score 0.6646
# F1 Score 0.5778
#
# Confusion Matrix
# 0.3
#
# Accuracy Score 0.7534
# F1 Score 0.6221
#
# Confusion Matrix
# 0.4
#
# Accuracy Score 0.7871
# F1 Score 0.6152
#
# Confusion Matrix
# 0.5
#
# Accuracy Score 0.8001
# F1 Score 0.5812
#
# Confusion Matrix
# 0.6
#
# Accuracy Score 0.8064
# F1 Score 0.5307
#
# Confusion Matrix
# 0.7
#
# Accuracy Score 0.7865
# F1 Score 0.4207
#
# Confusion Matrix
# 0.8
#
# Accuracy Score 0.7496
# F1 Score 0.2239
#
# Confusion Matrix
# 0.9
#
# Accuracy Score 0.7297
# F1 Score 0.0824
#
# Confusion Matrix

# %%
data_pred_custom_cutoff=[]
for i in range(0,len(pred_prob_test[:,1])):
    if np.array(pred_prob_test[:,1])[i]>0.4:
        a=1
    else:
        a=0
    data_pred_custom_cutoff.append(a)
sns.heatmap((metrics.confusion_matrix(y_test,data_pred_custom_cutoff)),annot=True,fmt='.4g');

# %%
tempdf = pd.concat([tempdf,res_df])

# %% [markdown]
# Model Tuning - K-NN

# %%
for i in range(1,9,2):
    KNN_Model = KNeighborsClassifier(n_neighbors=i,metric='euclidean')
    KNN_Model.fit(X_train_sc,y_train)
    y_test_p = KNN_Model.predict(X_test_sc)
    print(f'Accuracy Score for K={i} : ',KNN_Model.score(X_test_sc,y_test))
# Out:
# Accuracy Score for K=1 :  0.9633204633204633
# Accuracy Score for K=3 :  0.924066924066924
# Accuracy Score for K=5 :  0.9066924066924067
# Accuracy Score for K=7 :  0.8983268983268984

# %%
acc=[]
for i in range(1,20,2):
    KNN_Model = KNeighborsClassifier(n_neighbors=i,metric='euclidean')
    KNN_Model.fit(X_train_sc,y_train)
    y_test_p = KNN_Model.predict(X_test_sc)
    acc.append(KNN_Model.score(X_test_sc,y_test))
    
MCE = [1 - x for x in acc]
MCE
# Out:
# [0.03667953667953672,
#  0.07593307593307597,
#  0.0933075933075933,
#  0.10167310167310162,
#  0.11840411840411835,
#  0.13191763191763195,
#  0.13963963963963966,
#  0.14864864864864868,
#  0.16216216216216217,
#  0.16280566280566278]

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,20,2),MCE)

plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
# Out:
# Text(0, 0.5, 'Misclassification Error')

# %%
k=1
KNN_Model = KNeighborsClassifier(n_neighbors=k,metric='euclidean')
KNN_Model.fit(X_train_sc,y_train)
KNN_train_p = KNN_Model.predict(X_train_sc)
KNN_test_p = KNN_Model.predict(X_test_sc)
print(f'Accuracy Score for K={k} : ',KNN_Model.score(X_test_sc,y_test))
# Out:
# Accuracy Score for K=1 :  0.9633204633204633

# %%
# KNN Model Scores
res_df=scores_train_test(KNN_Model,X_train_sc,X_test_sc,y_train,y_test,KNN_train_p,KNN_test_p,'Tuned')
# Out:
# KNeighborsClassifier
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_9a2a6_ th {
#           text-align: center;
#     }#T_9a2a6_row0_col0,#T_9a2a6_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_9a2a6_row0_col1,#T_9a2a6_row0_col2,#T_9a2a6_row0_col3,#T_9a2a6_row0_col4,#T_9a2a6_row0_col5,#T_9a2a6_row1_col1,#T_9a2a6_row1_col2,#T_9a2a6_row1_col3,#T_9a2a6_row1_col4,#T_9a2a6_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %% [markdown]
# Model Tuning - Random Forest

# %%
def rfrun(x_train,train_labels,x_test,max_f,no_est,max_dep,min_sam,min_spl):
    param_grid = {
        'criterion': ['gini'],
        'max_depth': max_dep, #,7,9],
        'max_features':max_f, #,32],
        'min_samples_leaf': min_sam,#15,20],
        'min_samples_split': min_spl,#75,60],
        'n_estimators': no_est
    }

    rfcl = RandomForestClassifier(random_state=1)

    grid_search = GridSearchCV(estimator = rfcl, param_grid = param_grid, cv = 5)
    grid_search.fit(x_train, train_labels)
    print(grid_search.best_params_)
    
    rfcl = grid_search.best_estimator_
    rfcl

    rfcl_y_predict_train = rfcl.predict(x_train)
    rfcl_y_predict_test = rfcl.predict(x_test)
    return(rfcl,rfcl_y_predict_train,rfcl_y_predict_test)

# %%
# rfcl_tuned,rfcl_y_predict_train,rfcl_y_predict_test = rfrun(
#     X_train,y_train,X_test,[20],[150],[3],[3],[9])

rfcl_tuned,rfcl_y_predict_train,rfcl_y_predict_test = rfrun(
    X_train,y_train,X_test,[8],[275],[18],[1],[3])

res_df = scores_train_test(rfcl_tuned,X_train,X_test,y_train,y_test,rfcl_y_predict_train,rfcl_y_predict_test,'Tuned')
# Out:
# {'criterion': 'gini', 'max_depth': 18, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 275}
# RandomForestClassifier
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_910f8_ th {
#           text-align: center;
#     }#T_910f8_row0_col0,#T_910f8_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_910f8_row0_col1,#T_910f8_row0_col2,#T_910f8_row0_col3,#T_910f8_row0_col4,#T_910f8_row0_col5,#T_910f8_row1_col1,#T_910f8_row1_col2,#T_910f8_row1_col3,#T_910f8_row1_col4,#T_910f8_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %% [markdown]
# Bagging Classifer

# %%
from sklearn.ensemble import BaggingClassifier
bgcl = BaggingClassifier(base_estimator=rfcl, n_estimators=150,random_state=0)

bgcl = bgcl.fit(X_train, y_train)
bgcl_y_predict_train = bgcl.predict(X_train)

# %%
bgcl_y_predict_test = bgcl.predict(X_test)
res_df = scores_train_test(bgcl,X_train,X_test,y_train,y_test,bgcl_y_predict_train,bgcl_y_predict_test,'Bagging')
# Out:
# BaggingClassifier
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_ebc0f_ th {
#           text-align: center;
#     }#T_ebc0f_row0_col0,#T_ebc0f_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_ebc0f_row0_col1,#T_ebc0f_row0_col2,#T_ebc0f_row0_col3,#T_ebc0f_row0_col4,#T_ebc0f_row0_col5,#T_ebc0f_row1_col1,#T_ebc0f_row1_col2,#T_ebc0f_row1_col3,#T_ebc0f_row1_col4,#T_ebc0f_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %% [markdown]
# AdaBoosting

# %%
from sklearn.ensemble import AdaBoostClassifier
abcl = AdaBoostClassifier(n_estimators=10, random_state=0)

abcl = abcl.fit(X_train, y_train)
abcl_y_predict_train = abcl.predict(X_train)

# %%
abcl_y_predict_test = bgcl.predict(X_test)
res_df = scores_train_test(abcl,X_train,X_test,y_train,y_test,abcl_y_predict_train,abcl_y_predict_test,'Boost')
# Out:
# AdaBoostClassifier
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_176a9_ th {
#           text-align: center;
#     }#T_176a9_row0_col0,#T_176a9_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_176a9_row0_col1,#T_176a9_row0_col2,#T_176a9_row0_col3,#T_176a9_row0_col4,#T_176a9_row0_col5,#T_176a9_row1_col1,#T_176a9_row1_col2,#T_176a9_row1_col3,#T_176a9_row1_col4,#T_176a9_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %% [markdown]
# GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(random_state=0)
gbcl = gbcl.fit(X_train, y_train)

gbcl_y_predict_train = gbcl.predict(X_train)

# %%
gbcl_y_predict_test = gbcl.predict(X_test)
res_df = scores_train_test(gbcl,X_train,X_test,y_train,y_test,gbcl_y_predict_train,gbcl_y_predict_test,'Boost')
# Out:
# GradientBoostingClassifier
# ********************************
#
# Display Metrics of Train and Test Data
# ***************************************
# <style  type="text/css" >
#     #T_f99df_ th {
#           text-align: center;
#     }#T_f99df_row0_col0,#T_f99df_row1_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_f99df_row0_col1,#T_f99df_row0_col2,#T_f99df_row0_col3,#T_f99df_row0_col4,#T_f99df_row0_col5,#T_f99df_row1_col1,#T_f99df_row1_col2,#T_f99df_row1_col3,#T_f99df_row1_col4,#T_f99df_row1_col5{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
tempdf = pd.concat([tempdf,res_df])

# %%
tempdf
# Out:
#                                    Scores  Precision  Recall  F-Score  \
# 0           LogisticRegression_Base_Train      72.35   49.46    58.76
# 1            LogisticRegression_Base_Test      69.26   50.47    58.39
# 0   LinearDiscriminantAnalysis_Base_Train      70.85   49.27    58.12
# 1    LinearDiscriminantAnalysis_Base_Test      70.36   50.94    59.10
# 0       RandomForestClassifier_Base_Train     100.00  100.00   100.00
# 1        RandomForestClassifier_Base_Test      97.62   96.93    97.28
# 0         KNeighborsClassifier_Base_Train      91.86   95.00    93.40
# 1          KNeighborsClassifier_Base_Test      81.49   85.14    83.28
# 0                   GaussianNB_Base_Train      54.91   66.21    60.04
# 1                    GaussianNB_Base_Test      56.67   65.09    60.59
# 0          LogisticRegression_Tuned_Train      78.75   45.74    57.87
# 1           LogisticRegression_Tuned_Test      75.56   47.41    58.26
# ...

# %%
tt = tempdf.copy()

# %%
tt = tt.reset_index().drop('index',axis=1)

# %%
tt['Model']=tt['Scores'].str.split('_',n=1,expand=True)[0]
tt['TT']=tt['Scores'].str.split('_',n=1,expand=True)[1].str.split('_',n=1,expand=True)[0]
tt['BT']=tt['Scores'].str.split('_',n=1,expand=True)[1].str.split('_',n=1,expand=True)[1]

# %%
tt.drop('Scores',axis=1,inplace=True)

# %%
tt = tt[['Model','BT','TT','Precision','Recall','F-Score','Accuracy','AUC']]

# %%
tt_report = tt[((tt['TT']!='Bagging') & (tt['TT']!='Boost'))]
tt_bag = tt[(tt['TT']=='Bagging')]
tt_boost = tt[(tt['TT']=='Boost')]

# %%
trg = tt_report.groupby(['Model','TT','BT'])['Precision','Recall','F-Score','Accuracy','AUC'].max().sort_values(by=['Model','TT','BT'],ascending=False)
trg
# Out:
#                                         Precision  Recall  F-Score  Accuracy  \
# Model                      TT    BT
# RandomForestClassifier     Tuned Train      95.12   74.44    83.52     91.73
#                                  Test       86.48   64.86    74.12     87.64
#                            Base  Train     100.00  100.00   100.00    100.00
#                                  Test       97.62   96.93    97.28     98.52
# LogisticRegression         Tuned Train      78.75   45.74    57.87     81.25
#                                  Test       75.56   47.41    58.26     81.47
#                            Base  Train      72.35   49.46    58.76     80.45
#                                  Test       69.26   50.47    58.39     80.37
# LinearDiscriminantAnalysis Tuned Train      78.75   45.74    57.87     80.01
#                                  Test       75.56   47.41    58.26     80.76
#                            Base  Train      70.85   49.27    58.12     80.01
# ...

# %%
trg_bag = tt_bag.groupby(['Model','TT','BT'])['Precision','Recall','F-Score','Accuracy','AUC'].max().sort_values(by=['Model','TT','BT'],ascending=False)
trg_bag
# Out:
#                                  Precision  Recall  F-Score  Accuracy     AUC
# Model             TT      BT
# BaggingClassifier Bagging Train     100.00   99.61    99.80     99.89  100.00
#                           Test       97.04   92.69    94.81     97.23   99.34

# %%
trg_boost = tt_boost.groupby(['Model','TT','BT'])['Precision','Recall','F-Score','Accuracy','AUC'].max().sort_values(by=['Model','TT','BT'],ascending=False)
trg_boost
# Out:
#                                         Precision  Recall  F-Score  Accuracy  \
# Model                      TT    BT
# GradientBoostingClassifier Boost Train      90.41   69.25    78.42     89.27
#                                  Test       86.05   61.08    71.45     86.68
# AdaBoostClassifier         Boost Train      68.70   43.00    52.89     78.43
#                                  Test       97.04   92.69    94.81     77.22
#
#                                           AUC
# Model                      TT    BT
# GradientBoostingClassifier Boost Train  95.66
#                                  Test   93.17
# AdaBoostClassifier         Boost Train  81.79
#                                  Test   79.06

# %%
metdf = ((trg.T)
         .reset_index()).rename(columns={'index': 'Model'})

metdf_bag = ((trg_bag.T)
         .reset_index()).rename(columns={'index': 'Model'})

metdf_boost = ((trg_boost.T)
         .reset_index()).rename(columns={'index': 'Model'})

# %%
display_dataframe(metdf)
# Out:
# <style  type="text/css" >
#     #T_97562_ th {
#           text-align: center;
#     }#T_97562_row0_col0,#T_97562_row1_col0,#T_97562_row2_col0,#T_97562_row3_col0,#T_97562_row4_col0{
#             width:  5em;
#             text-align:  left;
# ...

# %%
display_dataframe(metdf_bag)
# Out:
# <style  type="text/css" >
#     #T_a3a84_ th {
#           text-align: center;
#     }#T_a3a84_row0_col0,#T_a3a84_row1_col0,#T_a3a84_row2_col0,#T_a3a84_row3_col0,#T_a3a84_row4_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_a3a84_row0_col1,#T_a3a84_row0_col2,#T_a3a84_row1_col1,#T_a3a84_row1_col2,#T_a3a84_row2_col1,#T_a3a84_row2_col2,#T_a3a84_row3_col1,#T_a3a84_row3_col2,#T_a3a84_row4_col1,#T_a3a84_row4_col2{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
display_dataframe(metdf_boost)
# Out:
# <style  type="text/css" >
#     #T_7072b_ th {
#           text-align: center;
#     }#T_7072b_row0_col0,#T_7072b_row1_col0,#T_7072b_row2_col0,#T_7072b_row3_col0,#T_7072b_row4_col0{
#             width:  5em;
#             text-align:  left;
#         }#T_7072b_row0_col1,#T_7072b_row0_col2,#T_7072b_row0_col3,#T_7072b_row0_col4,#T_7072b_row1_col1,#T_7072b_row1_col2,#T_7072b_row1_col3,#T_7072b_row1_col4,#T_7072b_row2_col1,#T_7072b_row2_col2,#T_7072b_row2_col3,#T_7072b_row2_col4,#T_7072b_row3_col1,#T_7072b_row3_col2,#T_7072b_row3_col3,#T_7072b_row3_col4,#T_7072b_row4_col1,#T_7072b_row4_col2,#T_7072b_row4_col3,#T_7072b_row4_col4{
#             width:  5em;
#             height:  3em;
#             text-align:  right;
#             border-color:  white;
#             border-style:  solid;
# ...

# %%
df_test.drop('Attrition',axis=1,inplace=True)

# %%
final_model = rfcl_tuned.fit(X,y)

# %%
#rf_output = rfcl.predict(df_test.drop('EmployeeID',axis=1))

rf_output = final_model.predict(df_test.drop('EmployeeID',axis=1))

# %%
rf_output
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
df_test['Attrition']= rf_output

# %%
df_test[['EmployeeID','Attrition']].to_csv('./Hack_submission.csv',index=False)
